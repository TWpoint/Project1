# %% [markdown]
# # Task 1: Understand body language by gesture recognition with fully connected neural network

# %% [markdown]
# ## 1. Do literature search on gesture recognition and its application in Human-Robot Interaction. Summarize what you have learned.

# %% [markdown]
# ## 2. Referring to the previous example about building a neural network based classifier, use what you have learned to read the code for gesture classification below and design your own network architecture using fully connected layers.

# %% [markdown]
# ## 3. Run the model. Analyse and comment on the performance of your model based on fully connected layers.

# %%
import cv2
import numpy as np
import os
import torch
import itertools
import torch.utils.data as utils_data
import torch.nn as nn

# %% [markdown]
# ## 1) data preprocessing

# %% [markdown]
# Define a function to preprocess the images including resizing and binaryzation

# %%
def processSkinImage(filePath, resize_HW=48):
    # step 1
    # read the image
    original = cv2.imread(filename=filePath)

    # step 2
    # resize the image to
    image_resized = cv2.resize(original, (resize_HW, resize_HW))

    # step 3
    # convert the image from rgb to YCbCr
    image_ycbcr = cv2.cvtColor(image_resized, cv2.COLOR_BGR2YCR_CB)

    # step 4
    # get the central color of the image
    # expected the hand to be in the central of the image
    Cb_center_color = image_ycbcr[int(resize_HW/2), int(resize_HW/2), 1]
    Cr_center_color = image_ycbcr[int(resize_HW/2), int(resize_HW/2), 2]
    # set the range
    Cb_Difference = 15
    Cr_Difference = 10

    # step 5
    # detect skin pixels
    Cb = image_ycbcr[:, :, 1]
    Cr = image_ycbcr[:, :, 2]
    index = np.where((Cb >= Cb_center_color-Cb_Difference) & (Cb <= Cb_center_color+Cb_Difference)
                     & (Cr >= Cr_center_color-Cr_Difference) & (Cr <= Cr_center_color+Cr_Difference))

    # Mark detected pixels and output
    image_output = np.zeros((resize_HW, resize_HW))
    image_output[index] = 255

    # show image
    # cv2.imshow("", image_output)
    # cv2.waitKey(0)
    return image_output

# %% [markdown]
# Deal with all the images using the function defined above.
# The processed data is stored in a new folder 'dataset_processed'.
#
# Generate labels for each class. (class 0, 1, ..., num_classes)

# %%
path = './dataset/dataset/images'
path_processed = './dataset_processed/images'

# -------------------images processing--------------
for mainDir, subDir, fileList in os.walk(path):
    for file in fileList:
        currentPath = os.path.join(mainDir, file)
        processedImage = processSkinImage(currentPath)

        new_mainDir = path_processed + mainDir.split(path)[-1]
        if not os.path.exists(new_mainDir):
            os.makedirs(new_mainDir)
        cv2.imwrite(os.path.join(new_mainDir, file), processedImage)

# -----------------label generation----------------
label_path = './dataset_processed/labels'
if not os.path.exists(label_path):
    os.makedirs(label_path)

files = os.listdir(path)
for i, file in enumerate(files):
    subclass_label_path = os.path.join(label_path, file+'.txt')
    with open(subclass_label_path, 'w') as f:
        f.write('#label\n')
    for _ in range(len(os.listdir(os.path.join(path_processed, file)))):
        with open(subclass_label_path, 'a') as f:
            f.write('{:d}\n'.format(i))
    f.close()

# %% [markdown]
# ## 2) load data

# %%
Image = []
path_images = './dataset_processed/images'
for mainDir, subDir, fileList in os.walk(path_images):
    for file in fileList:
        currentPath = os.path.join(mainDir, file)
        Image.append(cv2.imread(currentPath)[:, :, 0])
Image = np.array(Image)
dataset_size, H, W = Image.shape
# for FCNN model, the image need to be stretched into one dimension: (b, h, w)->(b, h*w)
Image = Image.reshape(dataset_size, -1)


Label = []
path_labels = './dataset_processed/labels'
for file in os.listdir(path_labels):
    Label.append(np.loadtxt(os.path.join(path_labels, file)))
Label = np.array(list(itertools.chain.from_iterable(Label)))
num_classes = int(np.max(Label))+1

# %% [markdown]
# ## 3) build your own neural network based on fully connected layers.

# %% [markdown]
# Design the neural network architecture

# %%
class FCNNModel(nn.Module):
    def __init__(self, input_layer_size, hidden_layer_size, num_classes):
        super(FCNNModel, self).__init__()
        self.fc1 = nn.Sequential(
            nn.Linear(input_layer_size, hidden_layer_size),
            nn.BatchNorm1d(hidden_layer_size),
            nn.ReLU(),
        )
        self.fc2 = nn.Sequential(
            nn.Linear(hidden_layer_size, num_classes),
        )
    
    def forward(self, x):
        x = self.fc1(x)
        out = self.fc2(x)
        return out

# %% [markdown]
# instantiate your model, set a optimizer and define a loss function.

# %%
model = FCNNModel(input_layer_size=H*W, hidden_layer_size=int(H*W/2), num_classes=num_classes)
# if torch.cuda.is_available():
#     model = model.cuda()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=0.0001)
loss_func = nn.CrossEntropyLoss()

# %% [markdown]
# ## 4) train and test

# %% [markdown]
# Encapsulate data

# %%
dataset = utils_data.TensorDataset(torch.Tensor(Image), torch.LongTensor(Label))
split_ratio = 0.8
train_size = int(split_ratio * dataset_size)
test_size = dataset_size - train_size
train_set, test_set = utils_data.random_split(dataset, [train_size, test_size])
train_loader = utils_data.DataLoader(dataset=train_set, batch_size=8, shuffle=True)
test_loader = utils_data.DataLoader(dataset=test_set, batch_size=8, shuffle=True)
print('Data is ready!')
# Out:
# Data is ready!

# %% [markdown]
# The following is the training and testing process in detail.

# %%
best_accuracy = 0
for epoch in range(500):
    running_loss = 0.0
    train_acc = 0.0
    for step, (batch_image, batch_label) in enumerate(train_loader):
        model.train()
        # if torch.cuda.is_available():
        #     batch_image, batch_label = batch_image.cuda(), batch_label.cuda()
        batch_output = model(batch_image)
        batch_loss = loss_func(batch_output, batch_label)

        optimizer.zero_grad()
        batch_loss.backward()
        optimizer.step()

        running_loss += batch_loss.item()

        # train accuracy
        _, train_predicted = torch.max(batch_output.data, 1)
        train_acc += (train_predicted == batch_label).sum().item()

    train_acc /= train_size
    running_loss /= (step+1)

    # ----------test----------
    model.eval()
    test_acc = 0.0
    for test_image, test_label in test_loader:
        test_output = model(test_image)
        _, predicted = torch.max(test_output.data, 1)
        test_acc += (predicted == test_label).sum().item()
    test_acc /= test_size

    print('epoch={:d}\ttrain loss={:.6f}\ttrain accuracy={:.3f}\ttest accuracy={:.3f}'.format(
        epoch, running_loss, train_acc, test_acc))

    if test_acc >= best_accuracy:
        torch.save(model.state_dict(), './trained_models/FCNN_model.pkl')
        best_accuracy = test_acc
# Out:
# epoch=0	train loss=0.084479	train accuracy=0.952	test accuracy=0.625
# epoch=1	train loss=0.045563	train accuracy=1.000	test accuracy=0.812
# epoch=417	train loss=0.001065	train accuracy=1.000	test accuracy=0.812
# epoch=418	train loss=0.000598	train accuracy=1.000	test accuracy=0.812
# epoch=419	train loss=0.042256	train accuracy=1.000	test accuracy=0.812
# epoch=420	train loss=0.008078	train accuracy=1.000	test accuracy=0.750
# epoch=421	train loss=0.039459	train accuracy=0.984	test accuracy=0.750
# epoch=422	train loss=0.007605	train accuracy=1.000	test accuracy=0.750
# epoch=423	train loss=0.011949	train accuracy=1.000	test accuracy=0.688
# epoch=424	train loss=0.007306	train accuracy=1.000	test accuracy=0.750
# epoch=425	train loss=0.075189	train accuracy=0.984	test accuracy=0.750
# epoch=426	train loss=0.042380	train accuracy=0.984	test accuracy=0.750
# epoch=427	train loss=0.001609	train accuracy=1.000	test accuracy=0.750
# epoch=428	train loss=0.160217	train accuracy=0.952	test accuracy=0.750
# epoch=429	train loss=0.005444	train accuracy=1.000	test accuracy=0.562
# epoch=430	train loss=0.295159	train accuracy=0.919	test accuracy=0.750
# epoch=431	train loss=0.111598	train accuracy=0.952	test accuracy=0.750
# epoch=432	train loss=0.003820	train accuracy=1.000	test accuracy=0.562
# epoch=433	train loss=0.076573	train accuracy=0.968	test accuracy=0.688
# epoch=434	train loss=0.112663	train accuracy=0.984	test accuracy=0.750
# epoch=435	train loss=0.077538	train accuracy=0.968	test accuracy=0.812
# epoch=436	train loss=0.021843	train accuracy=1.000	test accuracy=0.750
# epoch=437	train loss=0.034570	train accuracy=0.968	test accuracy=0.750
# epoch=438	train loss=0.000368	train accuracy=1.000	test accuracy=0.750
# epoch=439	train loss=0.006504	train accuracy=1.000	test accuracy=0.750
# epoch=440	train loss=0.052547	train accuracy=0.984	test accuracy=0.750
# epoch=441	train loss=0.002370	train accuracy=1.000	test accuracy=0.750
# epoch=442	train loss=0.008596	train accuracy=1.000	test accuracy=0.750
# epoch=443	train loss=0.005263	train accuracy=1.000	test accuracy=0.750
# epoch=444	train loss=0.000720	train accuracy=1.000	test accuracy=0.750
# epoch=445	train loss=0.000354	train accuracy=1.000	test accuracy=0.812
# epoch=446	train loss=0.001124	train accuracy=1.000	test accuracy=0.812
# epoch=447	train loss=0.007340	train accuracy=1.000	test accuracy=0.750
# epoch=448	train loss=0.008751	train accuracy=1.000	test accuracy=0.750
# epoch=449	train loss=0.003278	train accuracy=1.000	test accuracy=0.750
# epoch=450	train loss=0.001280	train accuracy=1.000	test accuracy=0.750
# epoch=451	train loss=0.000727	train accuracy=1.000	test accuracy=0.750
# epoch=452	train loss=0.000147	train accuracy=1.000	test accuracy=0.750
# epoch=453	train loss=0.000740	train accuracy=1.000	test accuracy=0.750
# epoch=454	train loss=0.000420	train accuracy=1.000	test accuracy=0.750
# epoch=455	train loss=0.000169	train accuracy=1.000	test accuracy=0.750
# epoch=456	train loss=0.000676	train accuracy=1.000	test accuracy=0.750
# epoch=457	train loss=0.001462	train accuracy=1.000	test accuracy=0.750
